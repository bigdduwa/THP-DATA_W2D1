# %%
import pandas as pd
brevets_db = pd.read_csv("C:/Users/Victoire/OneDrive/Documents/THP/THP_DATA/Jour_6/data/publications-de-demandes-de-brevets-2020.csv", encoding='latin-1',sep=';')

brevets_db.dropna(how='all', axis = 1)
# Out:
#       numero_de_publication date_de_publication type_de_publication  \
# 0                 FR3086796          2020-04-03                  A1
# 1                 FR3084713          2020-02-07                  A3
# 2                 FR3084971          2020-02-14                  A1
# 3                 FR3086839          2020-04-10                  A1
# 4                 FR3084974          2020-02-14                  A1
# ...                     ...                 ...                 ...
# 14659             FR3092426          2020-08-07                  A1
# 14660             FR3092641          2020-08-14                  A1
# 14661             FR3092679          2020-08-14                  A1
# 14662             FR3093190          2020-08-28                  A1
# 14663             FR3095890          2020-11-13                  A1
#
#              type_de_demande numero_de_depot date_de_depot  \
# 0         Demande fran̤aise       FR1858935    2018-09-28
# ...
