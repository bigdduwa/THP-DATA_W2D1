# %%
import pandas as pd
fest_df = pd.read_json("C:/Users/Victoire/OneDrive/Documents/THP/THP_DATA/Jour_6/data/panorama-des-festivals.json")
fest_df = pd.json_normalize(fest_df.fields)

fest_df
# Out:
#     departement date_de_fin_ancien ndeg_identification code_insee  \
# 0            13         2019-02-02               MD202      13201
# 1            13         2019-03-23               MD085      13201
# 2            13         2019-03-24               MM019      13004
# 3            83         2019-03-29               MH018      83099
# 4            06         2019-04-10               MJ040      06029
# ..          ...                ...                 ...        ...
# 314          84         2018-11-16               MJ033      84003
# 315          84         2018-11-18               MJ036      84025
# 316          06         2018-11-25               MJ007      06029
# 317          13         2018-11-25               MD194      13201
# 318          06         2018-12-09               ME026      06088
#
#      periodicite   commune_principale  \
# 0       Annuelle            MARSEILLE
# 1       Annuelle            MARSEILLE
# 2       Annuelle                ARLES
# ...

# %%
fest_df['commune_principale'].value_counts().head(3)
# Out:
# MARSEILLE    56
# CANNES       17
# AVIGNON      16
# Name: commune_principale, dtype: int64

# %%
fest_df['mois_habituel_de_debut'].value_counts().head(1)
# Out:
# 07 (juillet)    90
# Name: mois_habituel_de_debut, dtype: int64
